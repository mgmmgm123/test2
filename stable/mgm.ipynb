# %%
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui/

# !git clone https://github.com/yesyeahvh123/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /content/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
# !git clone https://github.com/etherealxx/batchlinks-webui /content/stable-diffusion-webui/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/sd-webui-tunnels /content/stable-diffusion-webui/extensions/sd-webui-tunnels
# !git clone https://github.com/mcmonkeyprojects/sd-dynamic-thresholding /content/stable-diffusion-webui/extensions/sd-dynamic-thresholding
# !git clone https://github.com/hnmr293/sd-webui-cutoff /content/stable-diffusion-webui/extensions/sd-webui-cutoff
# !git clone https://github.com/AlUlkesh/sd_delete_button /content/stable-diffusion-webui/extensions/sd_delete_button
# !git clone https://github.com/Bing-su/dddetailer /content/stable-diffusion-webui/extensions/dddetailer
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon /content/stable-diffusion-webui/extensions/a1111-sd-webui-locon
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg /content/stable-diffusion-webui/extensions/stable-diffusion-webui-rembg
# !git clone https://github.com/ashen-sensored/stable-diffusion-webui-two-shot /content/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
# !git clone https://github.com/thomasasfk/sd-webui-aspect-ratio-helper /content/stable-diffusion-webui/extensions/sd-webui-aspect-ratio-helper
# !git clone https://github.com/Scholar01/sd-webui-mov2mov /content/stable-diffusion-webui/extensions/sd-webui-mov2mov
# %cd /content/stable-diffusion-webui
# !git reset --hard
# !git -C /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai reset --hard

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/24196 -d /content/stable-diffusion-webui/models/Stable-diffusion -o v0_8.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mgm123/gsmdg/resolve/main/0.7_0.5Basil_mix_fixed_0.5dalcefoRealistic_tallyV2_0.3AbyssOrangeMix2-Hard.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o 0.7_0.5Basil_mix_fixed_0.5dalcefoRealistic_tallyV2_0.3AbyssOrangeMix2-Hard.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/GRS0024/arc_realistic_models/resolve/main/Mixed/AbyssBasil/AOM2h_Basil_0.5.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o AbyssBasil/AOM2h_Basil_0.5.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mgm123/gsmdg/resolve/main/chilloutmix_NiPrunedFp32Fix.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o chilloutmix_NiPrunedFp32Fix.safetensors 
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mgm123/gsmdg/resolve/main/0.5_0.65chilloutmix_NiPrunedFp32Fix_0.35azaleablossomMIX-beta-Original-fp16-no-ema_0.5v0_8.ckp -d /content/stable-diffusion-webui/models/Stable-diffusion -o 0.5_0.65chilloutmix_NiPrunedFp32Fix_0.35azaleablossomMIX-beta-Original-fp16-no-ema_0.5v0_8.ckpt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/stable-diffusion-webui/models/VAE -o vae-ft-mse-840000-ema-pruned.ckpt
# !wget https://huggingface.co/Xynon/models/resolve/main/experimentals/TI/bad-image-v2-39000.pt -O /content/stable-diffusion-webui/embeddings/bad-image-v2-39000.pt 
# !wget https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt -O /content/stable-diffusion-webui/embeddings/bad_prompt.pt 
# !wget https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt -O /content/stable-diffusion-webui/embeddings/bad_prompt_version2.pt  
# !wget https://huggingface.co/nick-x-hacker/bad-artist/resolve/main/bad-artist.pt -O /content/stable-diffusion-webui/embeddings/bad-artist.pt 
# !wget https://huggingface.co/nick-x-hacker/bad-artist/resolve/main/bad-artist-anime.pt -O /content/stable-diffusion-webui/embeddings/bad-artist-anime.pt
# !wget https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt -O /content/stable-diffusion-webui/embeddings/bad-hands-5.pt
# !wget https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -O /content/stable-diffusion-webui/embeddings/EasyNegative.pt 
# !wget https://huggingface.co/yesyeahvh/mgm/resolve/main/NG_DeepNegative_V1_75T.pt -O /content/stable-diffusion-webui/embeddings/NG_DeepNegative_V1_75T.pt 
# !wget https://huggingface.co/yesyeahvh/ulzzang-6500/resolve/main/ulzzang-6500.pt -O /content/stable-diffusion-webui/embeddings/ulzzang-6500.pt
# !wget https://huggingface.co/yesyeahvh/mgm/resolve/main/PureErosFace_V1.pt -O /content/stable-diffusion-webui/embeddings/PureErosFace_V1.pt 
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/embeddings/happy512.pt -O /content/stable-diffusion-webui/embeddings/happy512.pt 
# !wget https://huggingfacehttps://huggingface.co/mgm123/gsmdg1/resolve/main/embeddings/ulzzang-6500-v1.1.bin -O /content/stable-diffusion-webui/embeddings/ulzzang-6500-v1.1.bin
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/embeddings/badhandv4.pt -O /content/stable-diffusion-webui/embeddings/badhandv4.pt

# !wget -O config.json https://raw.githubusercontent.com/yesyeahvh123/mgm/main/config1.json
# !mkdir -p "/content/stable-diffusion-webui/models/Lora"

# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/I_am_young22/iAmYoung22_hina.safetensors -O /content/stable-diffusion-webui/models/Lora/iAmYoung22_hina.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/lora-hanfugirl-v1-5.safetensors -O /content/stable-diffusion-webui/models/Lora/lora-hanfugirl-v1-5.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Korean_Doll_Likeness/koreanDollLikeness_v15.safetensors -O /content/stable-diffusion-webui/models/Lora/koreanDollLikeness_v15.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Fashion_Girl/fashionGirl_v50.safetensors -O /content/stable-diffusion-webui/models/Lora/fashionGirl_v50.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/xiaoshasha/xiaoshasha_xss10.safetensors -O /content/stable-diffusion-webui/models/Lora/xiaoshasha_xss10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Irene/irene_60.safetensors -O /content/stable-diffusion-webui/models/Lora/irene_60.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Nancy/nancy_V20.safetensors -O /content/stable-diffusion-webui/models/Lora/nancy_V20.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Suzy/suzy_V10.safetensors -O /content/stable-diffusion-webui/models/Lora/suzy_V10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Ros%C3%A8_Blackpink/rosBlackpink_v1.safetensors -O /content/stable-diffusion-webui/models/Lora/rosBlackpink_v1.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/kor_insta_girl_v7.safetensors -O /content/stable-diffusion-webui/models/Lora/kor_insta_girl_v7.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Cute_girl_mix4/cuteGirlMix4_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/cuteGirlMix4_v10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Momo/momo_V10.safetensors -O /content/stable-diffusion-webui/models/Lora/momo_V10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/breastInClass-_Better_Bodies/breastinclassBetter_v13.safetensors -O /content/stable-diffusion-webui/models/Lora/breastinclassBetter_v13.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Hipoly_3D_Model_LoRA/hipoly3DModelLora_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/hipoly3DModelLora_v10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/ChilloutMixss2.0/chilloutmixss20_v20.safetensors -O /content/stable-diffusion-webui/models/Lora/chilloutmixss20_v20.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/ChilloutMixss3.0/chilloutmixss30_v30.safetensors -O /content/stable-diffusion-webui/models/Lora/chilloutmixss30_v30.safetensors
# !wget https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-lora.safetensors -O /content/stable-diffusion-webui/models/Lora/pastelmix-lora.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/theovercomer8sContrastFix_sd15.safetensors -O /content/stable-diffusion-webui/models/Lora/theovercomer8sContrastFix_sd15.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Light_and_Shadow/lightAndShadow_v10.safetensors -O /content/stable-diffusion-webui/models/Lora/lightAndShadow_v10.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/ShojoVibe%E5%B0%91%E5%A5%B3%E6%84%9F_/shojovibe_v11.safetensors -O /content/stable-diffusion-webui/models/Lora/shojovibe_v11.safetensors
# !wget https://huggingface.co/mgm123/gsmdg1/resolve/main/Kidmo/style/kidmoStyle_kidmoStyle.safetensors -O /content/stable-diffusion-webui/models/Lora/kidmoStyle_kidmoStyle.safetensors

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/stable-diffusion-webui/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
